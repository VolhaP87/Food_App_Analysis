# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('zomato.csv')
df
# Out:
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# 3      1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4      10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# ...                                                  ...
# 56247  Four Points by Sheraton Bengaluru, 43/3, White...
# 56248  Number 10, Garudachar Palya, Mahadevapura, Whi...
# 56249  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 56250  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 56251  ITPL Main Road, KIADB Export Promotion Industr...
#
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# ...

# %%
df = df.drop(columns=['address', 'phone'], axis=1)
df
# Out:
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 56247  Best Brews - Four Points by Sheraton Bengaluru...           No
# 56248                           Vinod Bar And Restaurant           No
# 56249  Plunge - Sheraton Grand Bengaluru Whitefield H...           No
# 56250  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 56251                       The Nest - The Den Bengaluru           No
#
#       book_table    rate votes                    location  \
# 0            Yes   4.1/5   775                Banashankari
# ...

# %%
df = df.rename(columns = {'approx_cost(for two people)' : 'approx_cost',\
                          'listed_in(type)' : 'type',\
                          'rate' : 'rating'})
df
# Out:
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 56247  Best Brews - Four Points by Sheraton Bengaluru...           No
# 56248                           Vinod Bar And Restaurant           No
# 56249  Plunge - Sheraton Grand Bengaluru Whitefield H...           No
# 56250  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 56251                       The Nest - The Den Bengaluru           No
#
#       book_table  rating votes                    location  \
# 0            Yes   4.1/5   775                Banashankari
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56252 entries, 0 to 56251
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          56236 non-null  object
#  1   online_order  56233 non-null  object
#  2   book_table    56194 non-null  object
#  3   rating        48414 non-null  object
#  4   votes         56174 non-null  object
#  5   location      56126 non-null  object
#  6   rest_type     55914 non-null  object
#  7   dish_liked    28027 non-null  object
#  8   cuisines      56049 non-null  object
#  9   approx_cost   55731 non-null  object
#  10  type          51642 non-null  object
# dtypes: object(11)
# memory usage: 4.7+ MB

# %%
df.dropna(subset=['name'],inplace=True)
df['online_order'].fillna('NA',inplace=True)
df['book_table'].fillna('NA',inplace=True)
df['rating'].fillna('0',inplace=True)
df['votes'].fillna('0',inplace=True)
df['location'].fillna('NA',inplace=True)
df['rest_type'].fillna('NA',inplace=True)
df['dish_liked'].fillna('NA',inplace=True)
df['cuisines'].fillna('NA',inplace=True)
df['approx_cost'].fillna('0',inplace=True)
df['type'].fillna('NA',inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 56236 entries, 0 to 56251
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          56236 non-null  object
#  1   online_order  56236 non-null  object
#  2   book_table    56236 non-null  object
#  3   rating        56236 non-null  object
#  4   votes         56236 non-null  object
#  5   location      56236 non-null  object
#  6   rest_type     56236 non-null  object
#  7   dish_liked    56236 non-null  object
#  8   cuisines      56236 non-null  object
#  9   approx_cost   56236 non-null  object
#  10  type          56236 non-null  object
# dtypes: object(11)
# memory usage: 5.1+ MB

# %%
df.duplicated().value_counts()
# Out:
# False    38413
# True     17823
# dtype: int64

# %%
df.drop_duplicates(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 38413 entries, 0 to 56251
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          38413 non-null  object
#  1   online_order  38413 non-null  object
#  2   book_table    38413 non-null  object
#  3   rating        38413 non-null  object
#  4   votes         38413 non-null  object
#  5   location      38413 non-null  object
#  6   rest_type     38413 non-null  object
#  7   dish_liked    38413 non-null  object
#  8   cuisines      38413 non-null  object
#  9   approx_cost   38413 non-null  object
#  10  type          38413 non-null  object
# dtypes: object(11)
# memory usage: 3.5+ MB

# %%
df = df[df["name"].str.contains("Rated|RATED") == False]
df = df[df["online_order"].str.contains("Rated|RATED") == False]
df = df[df["book_table"].str.contains("Rated|RATED") == False]
df = df[df["rating"].str.contains("Rated|RATED") == False]
df = df[df["votes"].str.contains("Rated|RATED") == False]
df = df[df["location"].str.contains("Rated|RATED") == False]
df = df[df["rest_type"].str.contains("Rated|RATED") == False]
df = df[df["dish_liked"].str.contains("Rated|RATED") == False]
df = df[df["cuisines"].str.contains("Rated|RATED") == False]
df = df[df["approx_cost"].str.contains("Rated|RATED") == False]
df = df[df["type"].str.contains("Rated|RATED") == False]
df
# Out:
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 56247  Best Brews - Four Points by Sheraton Bengaluru...           No
# 56248                           Vinod Bar And Restaurant           No
# 56249  Plunge - Sheraton Grand Bengaluru Whitefield H...           No
# 56250  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 56251                       The Nest - The Den Bengaluru           No
#
#       book_table  rating votes                    location  \
# 0            Yes   4.1/5   775                Banashankari
# ...

# %%
df = df[df["votes"].str.contains("0") == False]
df
# Out:
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 56244                         The Farm House Bar n Grill           No
# 56246                                            Bhagini           No
# 56247  Best Brews - Four Points by Sheraton Bengaluru...           No
# 56250  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 56251                       The Nest - The Den Bengaluru           No
#
#       book_table  rating votes                    location  \
# 0            Yes   4.1/5   775                Banashankari
# ...

# %%
df['id'] = df.index
first_column = df.pop('id')
  
df.insert(0, 'id', first_column)

df
# Out:
#           id                                               name online_order  \
# 0          0                                              Jalsa          Yes
# 1          1                                     Spice Elephant          Yes
# 2          2                                    San Churro Cafe          Yes
# 3          3                              Addhuri Udupi Bhojana           No
# 4          4                                      Grand Village           No
# ...      ...                                                ...          ...
# 56247  56247  Best Brews - Four Points by Sheraton Bengaluru...           No
# 56248  56248                           Vinod Bar And Restaurant           No
# 56249  56249  Plunge - Sheraton Grand Bengaluru Whitefield H...           No
# 56250  56250  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 56251  56251                       The Nest - The Den Bengaluru           No
#
# ...

# %%
df = df[df["online_order"].str.contains("Yes|No") == True]
df
# Out:
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 56244                         The Farm House Bar n Grill           No
# 56246                                            Bhagini           No
# 56247  Best Brews - Four Points by Sheraton Bengaluru...           No
# 56250  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 56251                       The Nest - The Den Bengaluru           No
#
#       book_table  rating votes                    location  \
# 0            Yes   4.1/5   775                Banashankari
# ...

# %%
df = df[df.rating != 'NEW']
df
# Out:
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 56244                         The Farm House Bar n Grill           No
# 56246                                            Bhagini           No
# 56247  Best Brews - Four Points by Sheraton Bengaluru...           No
# 56250  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 56251                       The Nest - The Den Bengaluru           No
#
#       book_table  rating votes                    location  \
# 0            Yes   4.1/5   775                Banashankari
# ...

# %%
df['rating'] = df['rating'].replace('-', 0)
df
# Out:
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 56244                         The Farm House Bar n Grill           No
# 56246                                            Bhagini           No
# 56247  Best Brews - Four Points by Sheraton Bengaluru...           No
# 56250  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 56251                       The Nest - The Den Bengaluru           No
#
#       book_table  rating votes                    location  \
# 0            Yes   4.1/5   775                Banashankari
# ...

# %%
df['rating'] = df['rating'].str.replace('/5', '')
df['rating'] = df['rating'].replace(np.nan, 0)
df
# Out:
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 56244                         The Farm House Bar n Grill           No
# 56246                                            Bhagini           No
# 56247  Best Brews - Four Points by Sheraton Bengaluru...           No
# 56250  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 56251                       The Nest - The Den Bengaluru           No
#
#       book_table rating votes                    location  \
# 0            Yes    4.1   775                Banashankari
# ...

# %%
df['rating'].unique()
# Out:
# array(['4.1', '3.8', '3.7', '3.6', '4.6', '4.0', '4.2', '3.9', '3.1',
#        '3.0', '3.2', '3.3', '2.8', '4.4', '4.3', '2.9', '3.5', '2.6',
#        '3.8 ', '3.4', '4.5', '2.5', '2.7', '4.7', '2.4', '2.3', '3.4 ',
#        '3.6 ', '4.8', '4.2 ', '3.9 ', '4.0 ', '4.1 ', '3.7 ', '3.1 ',
#        '2.9 ', '3.3 ', '2.8 ', '3.5 ', '2.7 ', '2.5 ', '2.6 ', '3.2 ',
#        '4.5 ', '4.3 ', '4.9', '2.1', '2.2', '2.0', '4.4 ', '1.8', '4.6 ',
#        '3.0 ', '0', '4.9 ', '4.8 ', '2.3 ', '4.7 ', '2.4 ', '2.1 ',
#        '2.0 ', '1.8 ', '2.2 '], dtype=object)

# %%
df = df[df["name"].str.contains(r'[Ãx][^A-Za-z]') == False]
df = df[df["online_order"].str.contains(r'[Ãx][^A-Za-z]') == False]
df = df[df["book_table"].str.contains(r'[Ãx][^A-Za-z]') == False]
df = df[df["rating"].str.contains(r'[Ãx][^A-Za-z]') == False]
df = df[df["votes"].str.contains(r'[Ãx][^A-Za-z]') == False]
df = df[df["location"].str.contains(r'[Ãx][^A-Za-z]') == False]
df = df[df["rest_type"].str.contains(r'[Ãx][^A-Za-z]') == False]
df = df[df["dish_liked"].str.contains(r'[Ãx][^A-Za-z]') == False]
df = df[df["cuisines"].str.contains(r'[Ãx][^A-Za-z]') == False]
df = df[df["approx_cost"].str.contains(r'[Ãx][^A-Za-z]') == False]
df = df[df["type"].str.contains(r'[Ãx][^A-Za-z]') == False]
df
# Out:
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 56244                         The Farm House Bar n Grill           No
# 56246                                            Bhagini           No
# 56247  Best Brews - Four Points by Sheraton Bengaluru...           No
# 56250  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 56251                       The Nest - The Den Bengaluru           No
#
#       book_table rating votes                    location  \
# 0            Yes    4.1   775                Banashankari
# ...

# %%
df = df[df["rating"].str.contains("0.0/5") == False]
df
# Out:
#           id                                               name online_order  \
# 0          0                                              Jalsa          Yes
# 1          1                                     Spice Elephant          Yes
# 2          2                                    San Churro Cafe          Yes
# 3          3                              Addhuri Udupi Bhojana           No
# 4          4                                      Grand Village           No
# ...      ...                                                ...          ...
# 56247  56247  Best Brews - Four Points by Sheraton Bengaluru...           No
# 56248  56248                           Vinod Bar And Restaurant           No
# 56249  56249  Plunge - Sheraton Grand Bengaluru Whitefield H...           No
# 56250  56250  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 56251  56251                       The Nest - The Den Bengaluru           No
#
# ...

# %%
df = df[(df['approx_cost']!='0')]
df
# Out:
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 56244                         The Farm House Bar n Grill           No
# 56246                                            Bhagini           No
# 56247  Best Brews - Four Points by Sheraton Bengaluru...           No
# 56250  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 56251                       The Nest - The Den Bengaluru           No
#
#       book_table rating votes                    location  \
# 0            Yes    4.1   775                Banashankari
# ...

# %%
df = df[(df['online_order']=='Yes') | (df['online_order']=='No')]
df
# Out:
#           id                                               name online_order  \
# 0          0                                              Jalsa          Yes
# 1          1                                     Spice Elephant          Yes
# 2          2                                    San Churro Cafe          Yes
# 3          3                              Addhuri Udupi Bhojana           No
# 4          4                                      Grand Village           No
# ...      ...                                                ...          ...
# 56247  56247  Best Brews - Four Points by Sheraton Bengaluru...           No
# 56248  56248                           Vinod Bar And Restaurant           No
# 56249  56249  Plunge - Sheraton Grand Bengaluru Whitefield H...           No
# 56250  56250  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 56251  56251                       The Nest - The Den Bengaluru           No
#
# ...

# %%
df['rating'].unique()
# Out:
# array(['4.1/5', '3.8/5', '3.7/5', '3.6/5', '4.6/5', '4.0/5', '4.2/5',
#        '3.9/5', '3.1/5', '3.0/5', '3.2/5', '3.3/5', '2.8/5', '4.4/5',
#        '4.3/5', 'NEW', '2.9/5', '3.5/5', '0', '2.6/5', '3.8 /5', '3.4/5',
#        '4.5/5', '2.5/5', '2.7/5', '4.7/5', '2.4/5', '2.2/5', '2.3/5',
#        '3.4 /5', '-', '3.6 /5', '4.8/5', '3.9 /5', '4.2 /5', '4.0 /5',
#        '4.1 /5', '3.7 /5', '3.1 /5', '2.9 /5', '3.3 /5', '2.8 /5',
#        '3.5 /5', '2.7 /5', '2.5 /5', '3.2 /5', '2.6 /5', '4.5 /5',
#        '4.3 /5', '4.4 /5', '4.9/5', '2.1/5', '2.0/5', '1.8/5', '4.6 /5',
#        '4.9 /5', '3.0 /5', '4.8 /5', '2.3 /5', '4.7 /5', '2.4 /5',
#        '2.1 /5', '2.2 /5', '2.0 /5', '1.8 /5'], dtype=object)

# %%
df = df[df["rating"].str.contains("-") == False]
df
# Out:
#           id                                               name online_order  \
# 0          0                                              Jalsa          Yes
# 1          1                                     Spice Elephant          Yes
# 2          2                                    San Churro Cafe          Yes
# 3          3                              Addhuri Udupi Bhojana           No
# 4          4                                      Grand Village           No
# ...      ...                                                ...          ...
# 56247  56247  Best Brews - Four Points by Sheraton Bengaluru...           No
# 56248  56248                           Vinod Bar And Restaurant           No
# 56249  56249  Plunge - Sheraton Grand Bengaluru Whitefield H...           No
# 56250  56250  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 56251  56251                       The Nest - The Den Bengaluru           No
#
# ...

# %%
df['rating'] = df['rating'].replace('NEW', 0)
df
# Out:
#           id                                               name online_order  \
# 0          0                                              Jalsa          Yes
# 1          1                                     Spice Elephant          Yes
# 2          2                                    San Churro Cafe          Yes
# 3          3                              Addhuri Udupi Bhojana           No
# 4          4                                      Grand Village           No
# ...      ...                                                ...          ...
# 56247  56247  Best Brews - Four Points by Sheraton Bengaluru...           No
# 56248  56248                           Vinod Bar And Restaurant           No
# 56249  56249  Plunge - Sheraton Grand Bengaluru Whitefield H...           No
# 56250  56250  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 56251  56251                       The Nest - The Den Bengaluru           No
#
# ...

# %%
df['rating'] = df['rating'].str.replace('/5', '')
df['rating'] = df['rating'].replace(np.nan, 0)
df
# Out:
#           id                                               name online_order  \
# 0          0                                              Jalsa          Yes
# 1          1                                     Spice Elephant          Yes
# 2          2                                    San Churro Cafe          Yes
# 3          3                              Addhuri Udupi Bhojana           No
# 4          4                                      Grand Village           No
# ...      ...                                                ...          ...
# 56247  56247  Best Brews - Four Points by Sheraton Bengaluru...           No
# 56248  56248                           Vinod Bar And Restaurant           No
# 56249  56249  Plunge - Sheraton Grand Bengaluru Whitefield H...           No
# 56250  56250  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 56251  56251                       The Nest - The Den Bengaluru           No
#
# ...

# %%
df = df[df["name"].str.contains("Ã") == False]
df
# Out:
#           id                                               name online_order  \
# 0          0                                              Jalsa          Yes
# 1          1                                     Spice Elephant          Yes
# 2          2                                    San Churro Cafe          Yes
# 3          3                              Addhuri Udupi Bhojana           No
# 4          4                                      Grand Village           No
# ...      ...                                                ...          ...
# 56247  56247  Best Brews - Four Points by Sheraton Bengaluru...           No
# 56248  56248                           Vinod Bar And Restaurant           No
# 56249  56249  Plunge - Sheraton Grand Bengaluru Whitefield H...           No
# 56250  56250  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 56251  56251                       The Nest - The Den Bengaluru           No
#
# ...

# %%
df[df['name']=='Brew and Barbeque - A Microbrewery Pub']
# Out:
#           id                                    name online_order book_table  \
# 7459    7459  Brew and Barbeque - A Microbrewery Pub          Yes        Yes
# 43743  43743  Brew and Barbeque - A Microbrewery Pub          Yes        Yes
# 44839  44839  Brew and Barbeque - A Microbrewery Pub          Yes        Yes
# 45519  45519  Brew and Barbeque - A Microbrewery Pub          Yes        Yes
#
#       rating votes      location          rest_type  \
# 7459     4.7  5746  Marathahalli  Microbrewery, Pub
# 43743   4.6   5894  Marathahalli  Microbrewery, Pub
# 44839   4.6   5894  Marathahalli  Microbrewery, Pub
# 45519   4.6   5913  Marathahalli  Microbrewery, Pub
#
#                                               dish_liked  \
# 7459   Bbq Platter, Craft Beer, Cocktails, Nachos, Pi...
# 43743  Bbq Platter, Craft Beer, Cocktails, Nachos, Pi...
# 44839  Craft Beer, Bbq Platter, Cocktails, Nachos, Pi...
# 45519  Craft Beer, Bbq Platter, Cocktails, Nachos, Pi...
#
# ...

# %%
df.to_csv('zomatocleaned.csv', encoding='UTF-8')

# %%
# For a high-level overview of the hotels, provide us the top 5 most voted hotels in the delivery category.

SELECT name, votes, rating FROM `zomato`
WHERE type='Delivery' 
ORDER BY votes DESC 
LIMIT 5;

# %%
#The rating of a hotel is a key identifier in determining a restaurant’s performance. Hence for a particular location called Banashankari find out the top 5 highly rated hotels in the delivery category.
SELECT name, rating, location, type FROM `zomato`
WHERE type='Delivery' AND location='Banashankari' 
ORDER BY rating DESC 
LIMIT 5;


Values:
    Onesta, 4.6, Banashankari, Delivery, 
    Ayodhya Upachar, 4.3, Banashankari, Delivery, 
    Corner House Ice Cream, 4.3, Banashankari, Delivery, 
    Mojo Pizza - 2X Toppings, 4.2, Banashankari, Delivery, 
    Smacznego, 4.2, Banashankari, Delivery,

# %%
# compare the ratings of the cheapest and most expensive hotels in Indiranagar.

SELECT rating AS rating1,
        (SELECT rating AS rating2
        FROM `zomato`
        WHERE location='Indiranagar'
        ORDER BY approx_cost DESC
        LIMIT 1)
    FROM `zomato` 
    WHERE location='Indiranagar' 
    ORDER BY approx_cost 
    LIMIT 1;


Headers: 
    rating1, rating2, 
    
    Values:
    3.7, 4.5,

# %%
# Online ordering of food has exponentially increased over time. 
# Compare the total votes of restaurants that provide online ordering services and 
# those who don’t provide online ordering service.
SELECT SUM(votes) AS total_votes, online_order
FROM `zomato` 
GROUP BY online_order;

 Headers: 
    total_votes, online_order, 
    
    Values:
    1385573, Yes, 
    879446, No,

# %%
# Number of votes defines how much the customers are involved with the service provided by the restaurants
# For each Restaurant type, find out the number of restaurants, total votes, and average rating. 
# Display the data with the highest votes on the top( if the first row of output is NA display the remaining rows).
SELECT type, COUNT(type) AS number_of_restaurants, SUM(votes) AS total_votes, AVG(rating) AS avg_rating
FROM `zomato` 
WHERE type NOT LIKE 'NA'
GROUP BY type
ORDER BY total_votes DESC;

Values:
    Delivery, 5955, 697876, 3.27471, 
    Dine-out, 2162, 545242, 3.40870, 
    Buffet, 155, 60884, 3.65290, 
    Desserts, 485, 55675, 3.44619, 
    Cafes, 357, 50666, 3.33697, 
    Drinks & nightlife, 24, 16017, 3.56250, 
    Pubs and bars, 16, 9877, 3.93750,

# %%
# What is the most liked dish of the most-voted restaurant on Zomato
#(as the restaurant has a tie-up with Zomato, the restaurant compulsorily provides 
# online ordering and delivery facilities.
SELECT name, dish_liked, rating, votes
    FROM `zomato`
    WHERE online_order='Yes' AND location='Marathahalli'
    ORDER BY votes DESC
    LIMIT 1;

# %%
# To increase the maximum profit, Zomato is in need to expand its business. 
# For doing so Zomato wants the list of the top 15 restaurants which have min 150 votes, 
# have a rating greater than 3, and is currently not providing online ordering. 
# Display the restaurants with highest votes on the top.

SELECT name, votes, rating, online_order
FROM `zomato`
WHERE votes>=150 AND rating>3 AND online_order='No'
ORDER BY votes DESC
LIMIT 15;

 Values:
    Toit, 4.7, 14956, No, 
    Truffles, 4.7, 14726, No, 
    AB's - Absolute Barbecues, 4.8, 12121, No, 
    The Black Pearl, 4.7, 10550, No, 
    Big Pitcher, 4.6, 9300, No, 
    Arbor Brewing Company, 4.5, 8419, No, 
    Prost Brew Pub, 4.5, 7871, No, 
    The Black Pearl, 4.8, 7284, No, 
    Barbeque Nation, 4.7, 7270, No, 
    Flechazo, 4.7, 7154, No, 
    The Hole in the Wall Cafe, 4.6, 7137, No,
